# %%
import pandas as pd
df = pd.read_csv('/Python/spotify-2023.csv', delimiter=',')

df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                  147  141381703                  43  ...  125   B  Major
# 1                   48  133716286                  48  ...   92  C#  Major
# 2                  113  140003974                  94  ...  138   F  Major
# 3                  100  800840817                 116  ...  170   A  Major
# 4                   50  303236322                  84  ...  144   A  Minor
# ..                 ...        ...                 ...  ...  ...  ..    ...
# 948                  0   91473363                  61  ...  144   A  Major
# 949                  0  121871870                   4  ...  166  F#  Major
# 950                  0   73513683                   2  ...   92  C#  Major
# 951                  0  133895612                  29  ...   97  C#  Major
# 952                  2   96007391                  27  ...   90   E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0               80         89       83             31                   0
# 1               71         61       74              7                   0
# 2               51         32       53             17                   0
# 3               55         58       72             11                   0
# 4               65         23       80             14                  63
# ..             ...        ...      ...            ...                 ...
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [953 rows x 24 columns]

# %%
#Lista de columnas a eliminar, se hace una variable tipo lista
cols_to_drop = [
    'in_apple_playlists',
    'in_apple_charts' ,
    'in_deezer_playlists' ,
    'in_deezer_charts' ,
    'in_shazam_charts'
]

#Función que permite eliminar las columnas
df.drop(columns=cols_to_drop, inplace=True)
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  bpm key   mode  danceability_%  valence_%  \
# 0                  147  141381703  125   B  Major              80         89
# 1                   48  133716286   92  C#  Major              71         61
# 2                  113  140003974  138   F  Major              51         32
# 3                  100  800840817  170   A  Major              55         58
# 4                   50  303236322  144   A  Minor              65         23
# ..                 ...        ...  ...  ..    ...             ...        ...
# 948                  0   91473363  144   A  Major              60         24
# 949                  0  121871870  166  F#  Major              42          7
# 950                  0   73513683   92  C#  Major              80         81
# 951                  0  133895612   97  C#  Major              82         67
# 952                  2   96007391   90   E  Minor              61         32
#
#      energy_%  acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 0          83              31                   0           8              4
# 1          74               7                   0          10              4
# 2          53              17                   0          31              6
# 3          72              11                   0          11             15
# 4          80              14                  63          11              6
# ..        ...             ...                 ...         ...            ...
# 948        39              57                   0           8              3
# 949        24              83                   1          12              6
# 950        67               4                   0           8              6
# 951        77               8                   0          12              5
# 952        67              15                   0          11              5
#
# [953 rows x 19 columns]

# %%
#Función que permite filtrar en este caso es por 'released_year' 2023

df= df[df['released_year'] == 2023]

df
# Out:
#                               track_name  \
# 0    Seven (feat. Latto) (Explicit Ver.)
# 1                                   LALA
# 2                                vampire
# 4                         WHERE SHE GOES
# 5                               Sprinter
# ..                                   ...
# 381         I'm Not Here To Make Friends
# 382                            TRUSTFALL
# 385            VIBE (feat. Jimin of BTS)
# 398                                 Mu��
# 404                      Sugar Rush Ride
#
#                              artist(s)_name  artist_count  released_year  \
# 0                          Latto, Jung Kook             2           2023
# 1                               Myke Towers             1           2023
# 2                            Olivia Rodrigo             1           2023
# 4                                 Bad Bunny             1           2023
# 5                         Dave, Central Cee             2           2023
# ..                                      ...           ...            ...
# 381  Sam Smith, Calvin Harris, Jessie Reyez             3           2023
# 382                                    P!nk             1           2023
# 385                          TAEYANG, Jimin             2           2023
# 398             Steve Aoki, Tini, La Joaqui             3           2023
# 404                     TOMORROW X TOGETHER             1           2023
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 0                 7            14                   553                147
# 1                 3            23                  1474                 48
# 2                 6            30                  1397                113
# 4                 5            18                  3133                 50
# 5                 6             1                  2186                 91
# ..              ...           ...                   ...                ...
# 381               1            27                  1890                  0
# 382               1            27                  2098                 16
# 385               1            13                   415                  2
# 398               1            12                   658                  6
# 404               1            27                   359                  0
#
#        streams  in_apple_playlists  ...  bpm  key   mode danceability_%  \
# 0    141381703                  43  ...  125    B  Major             80
# 1    133716286                  48  ...   92   C#  Major             71
# 2    140003974                  94  ...  138    F  Major             51
# 4    303236322                  84  ...  144    A  Minor             65
# 5    183706234                  67  ...  141   C#  Major             92
# ..         ...                 ...  ...  ...  ...    ...            ...
# 381  103787664                  86  ...  115  NaN  Major             70
# 382  134255790                  88  ...  122   G#  Major             64
# 385  152850295                  15  ...  100  NaN  Major             79
# 398  120972253                  33  ...   90   A#  Minor             68
# 404  107642809                  12  ...  125   A#  Minor             71
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 0           89       83             31                   0           8
# 1           61       74              7                   0          10
# 2           32       53             17                   0          31
# 4           23       80             14                  63          11
# 5           66       58             19                   0           8
# ..         ...      ...            ...                 ...         ...
# 381         84       90             17                   0          41
# 382         25       89              0                   0          15
# 385         60       68              7                   0          26
# 398         83       71              3                   0          31
# 404         83       89              1                   0          17
#
#      speechiness_%
# 0                4
# 1                4
# 2                6
# 4                6
# 5               24
# ..             ...
# 381              6
# 382              9
# 385              4
# 398              8
# 404              9
#
# [175 rows x 24 columns]

# %%
#Debemos ordenarla por mes y día de lanzamiento

df.sort_values(by=['released_month'], ascending=True, inplace= True)

df
# Out:
# <ipython-input-18-6bd433005469>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by=['released_month'], ascending=True, inplace= True)
#                                         track_name  \
# 404                                Sugar Rush Ride
# 131                                            OMG
# 133          Shakira: Bzrp Music Sessions, Vol. 53
# 149                         El Gordo Trae El Mando
# 160                                            PRC
# ..                                             ...
# 113                        Mine (Taylor's Version)
# 144                                          QUEMA
# 193         Better Than Revenge (Taylor's Version)
# 21   I Can See You (Taylor���s Version) (From The
# 0              Seven (feat. Latto) (Explicit Ver.)
#
#                    artist(s)_name  artist_count  released_year  \
# 404           TOMORROW X TOGETHER             1           2023
# 131                      NewJeans             1           2023
# 133             Shakira, Bizarrap             2           2023
# 149                   Chino Pacas             1           2023
# 160     Natanael Cano, Peso Pluma             2           2023
# ..                            ...           ...            ...
# 113                  Taylor Swift             1           2023
# 144  Sog, Ryan Castro, Peso Pluma             3           2023
# 193                  Taylor Swift             1           2023
# 21                   Taylor Swift             1           2023
# 0                Latto, Jung Kook             2           2023
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 404               1            27                   359                  0
# 131               1             2                  1783                 27
# 133               1            11                  5724                 44
# 149               1            27                   539                 21
# 160               1            23                   961                 26
# ..              ...           ...                   ...                ...
# 113               7             7                    99                 15
# 144               7            13                   437                 31
# 193               7             7                    86                 11
# 21                7             7                   516                 38
# 0                 7            14                   553                147
#
#        streams  in_apple_playlists  ...  bpm  key   mode danceability_%  \
# 404  107642809                  12  ...  125   A#  Minor             71
# 131  430977451                  26  ...  127    A  Minor             80
# 133  721975598                 119  ...  122    D  Minor             78
# 149  255932395                   7  ...  140    G  Minor             74
# 160  436027885                  19  ...  138    G  Minor             78
# ..         ...                 ...  ...  ...  ...    ...            ...
# 113   36912123                  21  ...  121    G  Major             65
# 144   11599388                  17  ...   97  NaN  Major             79
# 193   30343206                   3  ...  146    B  Minor             50
# 21    52135248                  73  ...  123   F#  Major             69
# 0    141381703                  43  ...  125    B  Major             80
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 404         83       89              1                   0          17
# 131         74       77             36                   0          11
# 133         50       63             27                   0           9
# 149         96       80             18                   0           5
# 160         89       83             10                   0          12
# ..         ...      ...            ...                 ...         ...
# 113         49       78              0                   0          17
# 144         92       89              5                   0           6
# 193         67       89              0                   0          19
# 21          82       76              6                   0           6
# 0           89       83             31                   0           8
#
#      speechiness_%
# 404              9
# 131              4
# 133              5
# 149              5
# 160              5
# ..             ...
# 113              4
# 144              5
# 193              8
# 21               3
# 0                4
#
# [175 rows x 24 columns]

# %%
import altair as alt

grafico_barras = alt.Chart(df).mark_bar().encode(
    x=alt.X('streams:Q', title='Reproducciones'),
    y=alt.Y('track_name:N', sort='-x', title='Nombre de la Canción'),
    #con el -x o x podemos invertir si es ascendente o descendente
    color=alt.Color('artist(s)_name:N', legend=alt.Legend(title="Artista"))
).properties(
    title="Canciones más reproducidas en Spotify en 2023"
)

# Imprimir gráfico de barras
grafico_barras
# Out:
# alt.Chart(...)

# %%
grafico_barras.save('/Python/grafico_barras.html')

# %%
grafico_circulo = alt.Chart(df).mark_circle().encode(
    x=alt.X('bpm:Q', title='Beats Por Minuto (BPM)'),
    y=alt.Y('energy_%:Q', title='Energía (%)'),
    color=alt.Color('artist(s)_name:N', legend=alt.Legend(title="Artista")),
    tooltip=['track_name', 'artist(s)_name', 'bpm', 'energy_%']
).properties(
    title="Relación entre BPM y Energía de las Canciones en 2023"
)

# Imprimir gráfico de puntos
grafico_circulo
# Out:
# alt.Chart(...)

# %%
grafico_circulo.save('/Python/grafico_circulo.html')

# %%
# Agrupar el DataFrame por mes y día, y contar el número de canciones
grouped_df = df.groupby(['released_month', 'released_day']).size().reset_index(name='count')

# Generar gráfico de burbuja
grafico_burbuja = alt.Chart(grouped_df).mark_circle().encode(
    x=alt.X('released_day:O', title='Día del Mes'),
    y=alt.Y('released_month:O', title='Mes de Lanzamiento'),
    size=alt.Size('count:Q', title='Número de Canciones'),
    #count es número de canciones lanzadas por día
    color=alt.Color('count:Q', scale=alt.Scale(scheme='reds'), legend=alt.Legend(title="Número de Canciones")),
    tooltip=['released_month', 'released_day', 'count']
).properties(
    title="Número de Canciones lanzadas por Día y Mes en 2023",
    width=600
)

# Imprimir el gráfico de burbuja
grafico_burbuja
# Out:
# alt.Chart(...)

# %%
grafico_burbuja.save('/Python/grafico_burbuja.html')

# %%
# Generar gráficos de barras de conteo de canciones por Clave y Modo
grafico_barras_conteo = alt.Chart(df).mark_bar().encode(
    x=alt.X('key:O', title='Clave'),
    y=alt.Y('count():Q', title='Número de Canciones'),
    color='mode:N',
    tooltip=['key', 'mode', 'count()']
).properties(
    title="Número de Canciones por Clave y Modo"
).facet(
    column='mode:N'
)

# Imprimir los gráficos de barra
grafico_barras_conteo
# Out:
# alt.FacetChart(...)

# %%
grafico_barras_conteo.save('/Python/grafico_barras_conteo.html')

# %%
# Crear un nuevo DataFrame basado en df, dividir la columna de nombres de artistas si hay más de uno
df_artists = df.copy()
df_artists['artist(s)_name'] = df_artists['artist(s)_name'].str.split(', ')
df_exploded = df_artists.explode('artist(s)_name')

# Convertir 'streams' a int y sumar por artista
df_exploded['streams'] = df_exploded['streams'].astype(int)
#se convierten a entero para poder graficarlos

df_artist_streams = df_exploded.groupby('artist(s)_name').streams.sum().reset_index()

# Gráfico
mark_bar_artistas = alt.Chart(df_artist_streams).mark_bar().encode(
    x='streams:Q',
    y=alt.Y('artist(s)_name:N', sort='y'),
    tooltip=['artist(s)_name', 'streams']
).properties(title="Streams by Artist")

mark_bar_artistas
# Out:
# alt.Chart(...)
